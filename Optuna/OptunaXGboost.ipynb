# %%
# =========================
# OPTUNA + XGBOOST REGRESSION
# =========================
import optuna
import xgboost as xgb
from sklearn.model_selection import cross_val_score
import pandas as pd

# -------------------------
# Paramètres
# -------------------------
TRAIN_FILE = "../ressources/npyDS/DataSetLasso/train.csv"
VAL_FILE   = "../ressources/npyDS/DataSetLasso/val.csv"
TEST_FILE  = "../ressources/npyDS/DataSetLasso/test.csv"
Y_NAME = "y"

EARLY_STOPPING_ROUNDS = 50
NUM_ITERATIONS = 30000
RANDOM_STATE = 42

# %%
# -------------------------
# Chargement des données
# -------------------------
train_df = pd.read_csv(TRAIN_FILE)
val_df   = pd.read_csv(VAL_FILE)
test_df  = pd.read_csv(TEST_FILE)

y_train = train_df[Y_NAME].to_numpy()
X_train = train_df.drop(columns=[Y_NAME]).to_numpy()

y_val = val_df[Y_NAME].to_numpy()
X_val = val_df.drop(columns=[Y_NAME]).to_numpy()

X_test = test_df.to_numpy()

# %%
# -------------------------
# Objective Optuna
# -------------------------
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 500, 3000),
        "max_depth": trial.suggest_int("max_depth", 4, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 10.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 10.0),
        "random_state": 42,
        "tree_method": "hist",
        "objective": "reg:squarederror"
    }

    model = xgb.XGBRegressor(**params)

    score = cross_val_score(
        model,
        X_train,
        y_train,
        cv=3,
        scoring="r2",
        n_jobs=-1
    ).mean()

    return score

# %%
# -------------------------
# Lancement Optuna
# -------------------------
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Meilleurs paramètres :", study.best_params)
print("Meilleur R² :", study.best_value)
# Out:
# [I 2025-12-18 00:02:51,228] A new study created in memory with name: no-name-eb6fb3ef-ca98-4328-b406-c290d009c376
# [I 2025-12-18 00:03:10,523] Trial 0 finished with value: 0.9172300517414801 and parameters: {'n_estimators': 1796, 'max_depth': 6, 'learning_rate': 0.04007915640802488, 'subsample': 0.6669524748864966, 'colsample_bytree': 0.6309362266542007, 'min_child_weight': 7, 'reg_alpha': 3.361764433073583, 'reg_lambda': 5.955866838695907}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:03:30,646] Trial 1 finished with value: 0.895166916504481 and parameters: {'n_estimators': 2815, 'max_depth': 4, 'learning_rate': 0.013835447438848477, 'subsample': 0.8947165954979458, 'colsample_bytree': 0.8637026924188091, 'min_child_weight': 9, 'reg_alpha': 5.970428366013037, 'reg_lambda': 1.0188759655338009}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:03:38,313] Trial 2 finished with value: 0.9119583567260002 and parameters: {'n_estimators': 584, 'max_depth': 8, 'learning_rate': 0.03267586637371631, 'subsample': 0.6993398640056748, 'colsample_bytree': 0.9430258202843235, 'min_child_weight': 7, 'reg_alpha': 3.4968438247014113, 'reg_lambda': 0.3824494308354265}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:03:55,275] Trial 3 finished with value: 0.8849837589714132 and parameters: {'n_estimators': 2381, 'max_depth': 4, 'learning_rate': 0.015347476820670138, 'subsample': 0.792727498126887, 'colsample_bytree': 0.6060460066410742, 'min_child_weight': 8, 'reg_alpha': 9.5924201177919, 'reg_lambda': 6.532545122970166}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:04:17,381] Trial 4 finished with value: 0.9021002692652362 and parameters: {'n_estimators': 2698, 'max_depth': 5, 'learning_rate': 0.016765446773612133, 'subsample': 0.7836666119708605, 'colsample_bytree': 0.7397663926910835, 'min_child_weight': 5, 'reg_alpha': 7.288518815743741, 'reg_lambda': 4.414199741371504}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:04:24,394] Trial 5 finished with value: 0.8552304743440545 and parameters: {'n_estimators': 833, 'max_depth': 4, 'learning_rate': 0.011244308529803047, 'subsample': 0.7129291538308001, 'colsample_bytree': 0.8155054338858366, 'min_child_weight': 5, 'reg_alpha': 6.192368350272534, 'reg_lambda': 0.40107934542881085}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:04:39,429] Trial 6 finished with value: 0.9004479550655735 and parameters: {'n_estimators': 2052, 'max_depth': 4, 'learning_rate': 0.03510535932513882, 'subsample': 0.8341287788244991, 'colsample_bytree': 0.7224775710984309, 'min_child_weight': 9, 'reg_alpha': 7.031011523079304, 'reg_lambda': 5.121234267696787}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:05:06,554] Trial 7 finished with value: 0.9069649428617957 and parameters: {'n_estimators': 2988, 'max_depth': 9, 'learning_rate': 0.027046169273725888, 'subsample': 0.7758559472334008, 'colsample_bytree': 0.6305515087941577, 'min_child_weight': 5, 'reg_alpha': 9.587841713828206, 'reg_lambda': 9.29598146491982}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:05:20,666] Trial 8 finished with value: 0.8969669813551526 and parameters: {'n_estimators': 1309, 'max_depth': 9, 'learning_rate': 0.01742428793734654, 'subsample': 0.642796003453206, 'colsample_bytree': 0.6350647727918273, 'min_child_weight': 2, 'reg_alpha': 7.928053450665997, 'reg_lambda': 9.924344365466789}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:05:42,815] Trial 9 finished with value: 0.9131833738983938 and parameters: {'n_estimators': 2631, 'max_depth': 7, 'learning_rate': 0.037688397655719304, 'subsample': 0.9436328968184662, 'colsample_bytree': 0.9787688432540266, 'min_child_weight': 9, 'reg_alpha': 7.7501635031653375, 'reg_lambda': 4.155839870370813}. Best is trial 0 with value: 0.9172300517414801.
# [I 2025-12-18 00:05:59,525] Trial 10 finished with value: 0.9304072301669318 and parameters: {'n_estimators': 1571, 'max_depth': 6, 'learning_rate': 0.1459161921108025, 'subsample': 0.6099818460865548, 'colsample_bytree': 0.7112003407634814, 'min_child_weight': 2, 'reg_alpha': 0.1333922783458612, 'reg_lambda': 7.45141075804854}. Best is trial 10 with value: 0.9304072301669318.
# [I 2025-12-18 00:06:16,752] Trial 11 finished with value: 0.9299452413266635 and parameters: {'n_estimators': 1619, 'max_depth': 6, 'learning_rate': 0.10799910706783176, 'subsample': 0.6001356403508771, 'colsample_bytree': 0.6958527113487608, 'min_child_weight': 1, 'reg_alpha': 0.35222603709471434, 'reg_lambda': 7.341395196959867}. Best is trial 10 with value: 0.9304072301669318.
# [I 2025-12-18 00:06:30,963] Trial 12 finished with value: 0.9293947337156655 and parameters: {'n_estimators': 1325, 'max_depth': 6, 'learning_rate': 0.15898061687508014, 'subsample': 0.6010545968481954, 'colsample_bytree': 0.7104505217544684, 'min_child_weight': 1, 'reg_alpha': 0.20822819951537674, 'reg_lambda': 7.822809644317508}. Best is trial 10 with value: 0.9304072301669318.
# [I 2025-12-18 00:06:47,525] Trial 13 finished with value: 0.9306284059868414 and parameters: {'n_estimators': 1336, 'max_depth': 7, 'learning_rate': 0.11400272244807949, 'subsample': 0.6124154252792973, 'colsample_bytree': 0.7760089449035279, 'min_child_weight': 3, 'reg_alpha': 0.5717683360039587, 'reg_lambda': 7.963802317318599}. Best is trial 13 with value: 0.9306284059868414.
# [I 2025-12-18 00:07:00,634] Trial 14 finished with value: 0.9267544941690288 and parameters: {'n_estimators': 1112, 'max_depth': 7, 'learning_rate': 0.07705210551109161, 'subsample': 0.7244026601462837, 'colsample_bytree': 0.7942776091935154, 'min_child_weight': 3, 'reg_alpha': 1.8641283044065964, 'reg_lambda': 8.456866448604417}. Best is trial 13 with value: 0.9306284059868414.
# [I 2025-12-18 00:07:13,927] Trial 15 finished with value: 0.9316213318137591 and parameters: {'n_estimators': 1961, 'max_depth': 10, 'learning_rate': 0.18949698380153257, 'subsample': 0.999286331662434, 'colsample_bytree': 0.7888492018680288, 'min_child_weight': 3, 'reg_alpha': 1.7290310544434144, 'reg_lambda': 8.604136180055216}. Best is trial 15 with value: 0.9316213318137591.
# [I 2025-12-18 00:07:35,754] Trial 16 finished with value: 0.9322364155027177 and parameters: {'n_estimators': 2094, 'max_depth': 10, 'learning_rate': 0.06665368607815546, 'subsample': 0.9952664320568952, 'colsample_bytree': 0.8608541448603461, 'min_child_weight': 3, 'reg_alpha': 2.0049680652384207, 'reg_lambda': 3.095286655475804}. Best is trial 16 with value: 0.9322364155027177.
# [I 2025-12-18 00:07:56,666] Trial 17 finished with value: 0.9301208705778881 and parameters: {'n_estimators': 2145, 'max_depth': 10, 'learning_rate': 0.06078438947718831, 'subsample': 0.9954571615160608, 'colsample_bytree': 0.8738463450199616, 'min_child_weight': 4, 'reg_alpha': 2.5265744951411286, 'reg_lambda': 2.688533964020992}. Best is trial 16 with value: 0.9322364155027177.
# [I 2025-12-18 00:08:09,841] Trial 18 finished with value: 0.9245836323429238 and parameters: {'n_estimators': 1974, 'max_depth': 10, 'learning_rate': 0.19256128124748062, 'subsample': 0.9855345543990904, 'colsample_bytree': 0.8799191834334673, 'min_child_weight': 3, 'reg_alpha': 4.349556714364039, 'reg_lambda': 2.7811817098294718}. Best is trial 16 with value: 0.9322364155027177.
# [I 2025-12-18 00:08:41,223] Trial 19 finished with value: 0.9334246791968983 and parameters: {'n_estimators': 2385, 'max_depth': 9, 'learning_rate': 0.06606408909826098, 'subsample': 0.9022943015962399, 'colsample_bytree': 0.8339825954140377, 'min_child_weight': 4, 'reg_alpha': 1.6041503273328053, 'reg_lambda': 2.687298641235361}. Best is trial 19 with value: 0.9334246791968983.
# [I 2025-12-18 00:09:12,949] Trial 20 finished with value: 0.9329177938989934 and parameters: {'n_estimators': 2402, 'max_depth': 9, 'learning_rate': 0.058242617052840326, 'subsample': 0.8827244877610659, 'colsample_bytree': 0.9176242402007909, 'min_child_weight': 6, 'reg_alpha': 1.6899147230532439, 'reg_lambda': 2.0853846029127476}. Best is trial 19 with value: 0.9334246791968983.
# [I 2025-12-18 00:09:47,071] Trial 21 finished with value: 0.9337884139080116 and parameters: {'n_estimators': 2372, 'max_depth': 9, 'learning_rate': 0.07118149610781188, 'subsample': 0.8902754112955981, 'colsample_bytree': 0.9198056955726724, 'min_child_weight': 6, 'reg_alpha': 1.4564067938649656, 'reg_lambda': 2.544795061109969}. Best is trial 21 with value: 0.9337884139080116.
# [I 2025-12-18 00:10:29,890] Trial 22 finished with value: 0.9345308738366352 and parameters: {'n_estimators': 2405, 'max_depth': 9, 'learning_rate': 0.055345064475685345, 'subsample': 0.875259408730012, 'colsample_bytree': 0.9287723857842272, 'min_child_weight': 6, 'reg_alpha': 1.1526361563898437, 'reg_lambda': 2.0335735941805013}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:11:12,306] Trial 23 finished with value: 0.9337804792604721 and parameters: {'n_estimators': 2552, 'max_depth': 8, 'learning_rate': 0.08434519289589483, 'subsample': 0.8606138870050559, 'colsample_bytree': 0.9885569325001345, 'min_child_weight': 6, 'reg_alpha': 1.0451574941413797, 'reg_lambda': 1.5098012869842043}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:11:47,213] Trial 24 finished with value: 0.9278459950829054 and parameters: {'n_estimators': 2591, 'max_depth': 8, 'learning_rate': 0.09483556212020168, 'subsample': 0.8350193157855448, 'colsample_bytree': 0.9987401932520005, 'min_child_weight': 7, 'reg_alpha': 3.302585472516536, 'reg_lambda': 1.676965817152377}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:12:21,223] Trial 25 finished with value: 0.9338810752751995 and parameters: {'n_estimators': 2277, 'max_depth': 8, 'learning_rate': 0.04882509363677932, 'subsample': 0.8520963150665843, 'colsample_bytree': 0.9389056506655783, 'min_child_weight': 6, 'reg_alpha': 1.0640002277198417, 'reg_lambda': 1.2679481266560158}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:12:46,833] Trial 26 finished with value: 0.9237713713567247 and parameters: {'n_estimators': 2281, 'max_depth': 8, 'learning_rate': 0.04931955283801568, 'subsample': 0.9350415214729232, 'colsample_bytree': 0.9255163733710355, 'min_child_weight': 8, 'reg_alpha': 4.294102014022184, 'reg_lambda': 3.6604718417937017}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:13:11,546] Trial 27 finished with value: 0.9253875824794672 and parameters: {'n_estimators': 1777, 'max_depth': 9, 'learning_rate': 0.02344843355836064, 'subsample': 0.8284581591001406, 'colsample_bytree': 0.952503047535355, 'min_child_weight': 6, 'reg_alpha': 2.7326220673650212, 'reg_lambda': 0.9986286282172736}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:13:42,964] Trial 28 finished with value: 0.9337648486310642 and parameters: {'n_estimators': 2234, 'max_depth': 8, 'learning_rate': 0.049112830572249314, 'subsample': 0.9308946038145642, 'colsample_bytree': 0.8982634885813379, 'min_child_weight': 8, 'reg_alpha': 1.2273550832538922, 'reg_lambda': 2.1027078669809165}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:14:21,245] Trial 29 finished with value: 0.9291985210934387 and parameters: {'n_estimators': 2900, 'max_depth': 9, 'learning_rate': 0.04472709184966422, 'subsample': 0.8556547028543197, 'colsample_bytree': 0.9601454003742335, 'min_child_weight': 10, 'reg_alpha': 2.769764077287574, 'reg_lambda': 5.430999643505329}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:14:42,007] Trial 30 finished with value: 0.9233373487001248 and parameters: {'n_estimators': 1920, 'max_depth': 7, 'learning_rate': 0.05278514532632821, 'subsample': 0.9559733707278222, 'colsample_bytree': 0.8359800914294864, 'min_child_weight': 7, 'reg_alpha': 3.9140057251217852, 'reg_lambda': 0.02711100545994971}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:15:22,604] Trial 31 finished with value: 0.9342416417541819 and parameters: {'n_estimators': 2527, 'max_depth': 8, 'learning_rate': 0.07683220815414135, 'subsample': 0.8761358315678431, 'colsample_bytree': 0.977492232912064, 'min_child_weight': 6, 'reg_alpha': 1.0160317322059602, 'reg_lambda': 1.2522109240245114}. Best is trial 22 with value: 0.9345308738366352.
# [I 2025-12-18 00:16:02,640] Trial 32 finished with value: 0.9346122224068519 and parameters: {'n_estimators': 2712, 'max_depth': 8, 'learning_rate': 0.07769795496815657, 'subsample': 0.910590685732523, 'colsample_bytree': 0.911590279282912, 'min_child_weight': 6, 'reg_alpha': 1.0279193891990641, 'reg_lambda': 1.2047178893707597}. Best is trial 32 with value: 0.9346122224068519.
# [I 2025-12-18 00:16:44,429] Trial 33 finished with value: 0.9348996536034013 and parameters: {'n_estimators': 2866, 'max_depth': 8, 'learning_rate': 0.08707403847178878, 'subsample': 0.9124637991418396, 'colsample_bytree': 0.9656997041931618, 'min_child_weight': 5, 'reg_alpha': 0.8946938731751999, 'reg_lambda': 1.0920346207182838}. Best is trial 33 with value: 0.9348996536034013.
# [I 2025-12-18 00:17:16,885] Trial 34 finished with value: 0.9298161418243321 and parameters: {'n_estimators': 2813, 'max_depth': 7, 'learning_rate': 0.1230192465486317, 'subsample': 0.9139755888200162, 'colsample_bytree': 0.9712619299257453, 'min_child_weight': 4, 'reg_alpha': 2.5616056252656167, 'reg_lambda': 0.8113704685192636}. Best is trial 33 with value: 0.9348996536034013.
# [I 2025-12-18 00:17:44,114] Trial 35 finished with value: 0.92301420507777 and parameters: {'n_estimators': 2761, 'max_depth': 8, 'learning_rate': 0.09863393400440161, 'subsample': 0.8748384223893629, 'colsample_bytree': 0.9029568918897, 'min_child_weight': 5, 'reg_alpha': 5.188751028536118, 'reg_lambda': 1.7947496112900907}. Best is trial 33 with value: 0.9348996536034013.
# [I 2025-12-18 00:18:21,548] Trial 36 finished with value: 0.935624676361417 and parameters: {'n_estimators': 2537, 'max_depth': 8, 'learning_rate': 0.08480378084198976, 'subsample': 0.9676817131340328, 'colsample_bytree': 0.9458424052601759, 'min_child_weight': 7, 'reg_alpha': 0.7873876099965322, 'reg_lambda': 0.5805733337751422}. Best is trial 36 with value: 0.935624676361417.
# [I 2025-12-18 00:19:01,673] Trial 37 finished with value: 0.9342194505398304 and parameters: {'n_estimators': 2889, 'max_depth': 7, 'learning_rate': 0.13248114083991577, 'subsample': 0.9630881740343128, 'colsample_bytree': 0.9416397767297989, 'min_child_weight': 7, 'reg_alpha': 0.7864685171193666, 'reg_lambda': 0.5469473795209769}. Best is trial 36 with value: 0.935624676361417.
# [I 2025-12-18 00:19:44,997] Trial 38 finished with value: 0.9347509532171455 and parameters: {'n_estimators': 2712, 'max_depth': 8, 'learning_rate': 0.09779195856155018, 'subsample': 0.9191351819400042, 'colsample_bytree': 0.8939978131724128, 'min_child_weight': 7, 'reg_alpha': 0.012153297846897004, 'reg_lambda': 0.15921362276978512}. Best is trial 36 with value: 0.935624676361417.
# [I 2025-12-18 00:20:31,739] Trial 39 finished with value: 0.9351377038915817 and parameters: {'n_estimators': 2971, 'max_depth': 8, 'learning_rate': 0.08350595828921362, 'subsample': 0.9247425911224905, 'colsample_bytree': 0.8993930443845467, 'min_child_weight': 8, 'reg_alpha': 0.011880884583438611, 'reg_lambda': 0.08006584380442339}. Best is trial 36 with value: 0.935624676361417.
# [I 2025-12-18 00:21:11,134] Trial 40 finished with value: 0.9357937734154661 and parameters: {'n_estimators': 2993, 'max_depth': 7, 'learning_rate': 0.08763675484099007, 'subsample': 0.9700702911996296, 'colsample_bytree': 0.852472208909238, 'min_child_weight': 9, 'reg_alpha': 0.018564423579985112, 'reg_lambda': 0.22538057440301235}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:21:50,751] Trial 41 finished with value: 0.9353622556682023 and parameters: {'n_estimators': 2981, 'max_depth': 7, 'learning_rate': 0.09032453466183986, 'subsample': 0.9711435259659276, 'colsample_bytree': 0.8509240160318875, 'min_child_weight': 9, 'reg_alpha': 0.007885253993062882, 'reg_lambda': 0.19790913940315302}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:22:19,901] Trial 42 finished with value: 0.9331162414900308 and parameters: {'n_estimators': 2997, 'max_depth': 5, 'learning_rate': 0.09317513876150792, 'subsample': 0.968187459750964, 'colsample_bytree': 0.847406622329701, 'min_child_weight': 10, 'reg_alpha': 0.0017978114645561616, 'reg_lambda': 0.6151085230989576}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:23:00,718] Trial 43 finished with value: 0.9339852647132042 and parameters: {'n_estimators': 2853, 'max_depth': 7, 'learning_rate': 0.15384717163654318, 'subsample': 0.95131675688365, 'colsample_bytree': 0.82254564832634, 'min_child_weight': 9, 'reg_alpha': 0.6085994261291456, 'reg_lambda': 0.08830146868213606}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:23:36,366] Trial 44 finished with value: 0.9342990175554174 and parameters: {'n_estimators': 3000, 'max_depth': 6, 'learning_rate': 0.08419319614933879, 'subsample': 0.973680427886147, 'colsample_bytree': 0.8567402093658194, 'min_child_weight': 8, 'reg_alpha': 0.5362958922660729, 'reg_lambda': 0.6391799854422751}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:24:16,153] Trial 45 finished with value: 0.9347197062949754 and parameters: {'n_estimators': 2862, 'max_depth': 7, 'learning_rate': 0.10749116916646317, 'subsample': 0.9330275629844818, 'colsample_bytree': 0.8795277786342012, 'min_child_weight': 9, 'reg_alpha': 0.543613643516076, 'reg_lambda': 0.8829389867149144}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:24:43,617] Trial 46 finished with value: 0.9204114870354839 and parameters: {'n_estimators': 2635, 'max_depth': 7, 'learning_rate': 0.11606063097291372, 'subsample': 0.7523169083870437, 'colsample_bytree': 0.9604282088768981, 'min_child_weight': 10, 'reg_alpha': 5.602282680365872, 'reg_lambda': 0.044280660468585906}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:24:49,860] Trial 47 finished with value: 0.9060719613699684 and parameters: {'n_estimators': 592, 'max_depth': 6, 'learning_rate': 0.029141689318531828, 'subsample': 0.9779520596013039, 'colsample_bytree': 0.8131122599475461, 'min_child_weight': 8, 'reg_alpha': 2.11883505762236, 'reg_lambda': 0.5074457780953519}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:25:18,684] Trial 48 finished with value: 0.9325178039641059 and parameters: {'n_estimators': 2909, 'max_depth': 5, 'learning_rate': 0.13405160680023978, 'subsample': 0.9498421126582597, 'colsample_bytree': 0.7594348894267666, 'min_child_weight': 9, 'reg_alpha': 0.2935363697579415, 'reg_lambda': 6.2532658008272195}. Best is trial 40 with value: 0.9357937734154661.
# [I 2025-12-18 00:25:47,725] Trial 49 finished with value: 0.9289462715421531 and parameters: {'n_estimators': 2512, 'max_depth': 6, 'learning_rate': 0.08463576934474991, 'subsample': 0.9204277967635709, 'colsample_bytree': 0.8743161193661629, 'min_child_weight': 9, 'reg_alpha': 2.1701374354015344, 'reg_lambda': 1.520924204504666}. Best is trial 40 with value: 0.9357937734154661.
# Meilleurs paramètres : {'n_estimators': 2993, 'max_depth': 7, 'learning_rate': 0.08763675484099007, 'subsample': 0.9700702911996296, 'colsample_bytree': 0.852472208909238, 'min_child_weight': 9, 'reg_alpha': 0.018564423579985112, 'reg_lambda': 0.22538057440301235}
# Meilleur R² : 0.9357937734154661

# %%
# -------------------------
# Entraînement final
# -------------------------
# best_params = study.best_params
# best_params.update({
#     "random_state": 42,
#     "tree_method": "hist",
#     "objective": "reg:squarederror"
# })
#
# final_model = xgb.XGBRegressor(**best_params)
#
# final_model.fit(
#     X_train, y_train,
#     eval_set=[(X_val, y_val)],
#     verbose=200
# )
