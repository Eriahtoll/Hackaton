# %%
# =========================
# TRAIN CATBOOST + PREDICTION
# =========================
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xgboost as xgb
import joblib
import optuna
from sklearn.model_selection import cross_val_score, train_test_split
import pandas as pd

# %%
# -------------------------
# Paramètres
# -------------------------
TRAIN_FILE = "../ressources/npyDS/DataSetLasso/train.csv"
VAL_FILE   = "../ressources/npyDS/DataSetLasso/val.csv"
TEST_FILE  = "../ressources/npyDS/DataSetLasso/test.csv"
SUBMISSION_FILE = "./ressources/results/CATBOOST_Lasso_Optuna.csv"
Y_NAME = "y"

EARLY_STOPPING_ROUNDS = 50
NUM_ITERATIONS = 30000
RANDOM_STATE = 42

# %%
# -------------------------
# Chargement des données
# -------------------------
train_df = pd.read_csv(TRAIN_FILE)
val_df   = pd.read_csv(VAL_FILE)
test_df  = pd.read_csv(TEST_FILE)

y_train = train_df[Y_NAME].to_numpy()
X_train = train_df.drop(columns=[Y_NAME]).to_numpy()

y_val = val_df[Y_NAME].to_numpy()
X_val = val_df.drop(columns=[Y_NAME]).to_numpy()

X_test = test_df.to_numpy()

# %%
def objective(trial):
    params = {
        'depth': trial.suggest_int('depth', 4, 8),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'l2_leaf_reg': trial.suggest_int('l2_leaf_reg', 1, 10),
        'iterations': 2000,
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.6, 1.0),
        'random_seed': 42,
        'loss_function': 'Huber:delta=0.05',
        'eval_metric': 'MAE',
        'verbose': 0,
        'task_type': 'CPU'
    }

    model = xgb(**params)

    # Cross-validation
    score = cross_val_score(
        model,
        X_train,
        y_train,
        cv=3,
        scoring='r2'
    ).mean()

    return score

# %%
study = optuna.create_study(direction='maximize')  # on maximise R²
study.optimize(objective, n_trials=50)  # 50 essais, tu peux augmenter si tu veux plus de précision
print("Meilleurs paramètres :", study.best_params)
print("Meilleur score R² :", study.best_value)
# Out:
# [I 2025-12-17 22:36:41,988] A new study created in memory with name: no-name-7eb67e6e-2b88-46d9-b1aa-6bc357f590c1
# [I 2025-12-17 22:37:18,557] Trial 0 finished with value: 0.8979516057590144 and parameters: {'depth': 6, 'learning_rate': 0.029019628514081634, 'l2_leaf_reg': 10, 'subsample': 0.8666756638108309, 'colsample_bylevel': 0.713204740950334}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:37:43,953] Trial 1 finished with value: 0.8443685434471538 and parameters: {'depth': 5, 'learning_rate': 0.026971406516374394, 'l2_leaf_reg': 9, 'subsample': 0.6219775936734664, 'colsample_bylevel': 0.7915166180645159}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:38:53,073] Trial 2 finished with value: 0.7880562395274565 and parameters: {'depth': 8, 'learning_rate': 0.05924582150684593, 'l2_leaf_reg': 7, 'subsample': 0.8755409787440621, 'colsample_bylevel': 0.8398712109372369}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:39:22,532] Trial 3 finished with value: 0.2784457386457391 and parameters: {'depth': 5, 'learning_rate': 0.022873601617831148, 'l2_leaf_reg': 4, 'subsample': 0.8185144599349131, 'colsample_bylevel': 0.802022993910575}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:40:08,040] Trial 4 finished with value: 0.796724814294452 and parameters: {'depth': 7, 'learning_rate': 0.020870438790632752, 'l2_leaf_reg': 6, 'subsample': 0.793140085711675, 'colsample_bylevel': 0.8509129680298624}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:40:52,797] Trial 5 finished with value: 0.8865306048610585 and parameters: {'depth': 7, 'learning_rate': 0.019537928754949366, 'l2_leaf_reg': 7, 'subsample': 0.6954830070681491, 'colsample_bylevel': 0.7128716004848122}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:41:37,017] Trial 6 finished with value: 0.7990286426447764 and parameters: {'depth': 7, 'learning_rate': 0.0907088133012281, 'l2_leaf_reg': 7, 'subsample': 0.6748618540409368, 'colsample_bylevel': 0.8297120397324795}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:42:26,127] Trial 7 finished with value: 0.4808027613473987 and parameters: {'depth': 7, 'learning_rate': 0.038718700810743634, 'l2_leaf_reg': 4, 'subsample': 0.8856149191420493, 'colsample_bylevel': 0.6513839824799083}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:43:13,366] Trial 8 finished with value: 0.8380122177545407 and parameters: {'depth': 7, 'learning_rate': 0.026732971594490684, 'l2_leaf_reg': 8, 'subsample': 0.8292993088680414, 'colsample_bylevel': 0.732057298416232}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:43:35,347] Trial 9 finished with value: -68.90244861094436 and parameters: {'depth': 4, 'learning_rate': 0.059052504713828106, 'l2_leaf_reg': 1, 'subsample': 0.6444192676684247, 'colsample_bylevel': 0.9861507778826871}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:44:05,473] Trial 10 finished with value: 0.8683326673996921 and parameters: {'depth': 5, 'learning_rate': 0.011072606307472659, 'l2_leaf_reg': 10, 'subsample': 0.9986301511028527, 'colsample_bylevel': 0.605355783357214}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:44:39,548] Trial 11 finished with value: 0.8858238835951505 and parameters: {'depth': 6, 'learning_rate': 0.01460733602535766, 'l2_leaf_reg': 10, 'subsample': 0.7226607262174373, 'colsample_bylevel': 0.7203581703733472}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:45:13,613] Trial 12 finished with value: 0.8068131964012645 and parameters: {'depth': 6, 'learning_rate': 0.01714985113392355, 'l2_leaf_reg': 4, 'subsample': 0.7304305882283739, 'colsample_bylevel': 0.7056207071965671}. Best is trial 0 with value: 0.8979516057590144.
# [I 2025-12-17 22:46:25,969] Trial 13 finished with value: 0.9085775993770402 and parameters: {'depth': 8, 'learning_rate': 0.037131908555001, 'l2_leaf_reg': 8, 'subsample': 0.9481957612344127, 'colsample_bylevel': 0.6774015121344121}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:47:52,471] Trial 14 finished with value: 0.8172115722519141 and parameters: {'depth': 8, 'learning_rate': 0.036342772661186296, 'l2_leaf_reg': 9, 'subsample': 0.9738649242734985, 'colsample_bylevel': 0.6580902416568916}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:49:18,958] Trial 15 finished with value: 0.8694697075046132 and parameters: {'depth': 8, 'learning_rate': 0.048311950154040294, 'l2_leaf_reg': 9, 'subsample': 0.9335200584213921, 'colsample_bylevel': 0.6005804933598795}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:50:07,800] Trial 16 finished with value: 0.7355405295352271 and parameters: {'depth': 6, 'learning_rate': 0.04471685838751407, 'l2_leaf_reg': 10, 'subsample': 0.9225752294059729, 'colsample_bylevel': 0.7621540638215389}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:50:39,173] Trial 17 finished with value: -215.62625868923968 and parameters: {'depth': 4, 'learning_rate': 0.09136497270854177, 'l2_leaf_reg': 8, 'subsample': 0.8712592980963094, 'colsample_bylevel': 0.905559819387432}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:51:12,986] Trial 18 finished with value: -50.065287780792744 and parameters: {'depth': 5, 'learning_rate': 0.029777898252094946, 'l2_leaf_reg': 1, 'subsample': 0.9452408536836332, 'colsample_bylevel': 0.6663031322097083}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:51:54,487] Trial 19 finished with value: 0.06501450333377656 and parameters: {'depth': 6, 'learning_rate': 0.06505722651775032, 'l2_leaf_reg': 5, 'subsample': 0.7710304222127466, 'colsample_bylevel': 0.7574404212843745}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:53:19,786] Trial 20 finished with value: 0.7661343186087981 and parameters: {'depth': 8, 'learning_rate': 0.034999329403334806, 'l2_leaf_reg': 8, 'subsample': 0.8495041033637349, 'colsample_bylevel': 0.676140782866764}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:54:18,912] Trial 21 finished with value: 0.8965650796942816 and parameters: {'depth': 7, 'learning_rate': 0.019673537569712192, 'l2_leaf_reg': 7, 'subsample': 0.7382982211480714, 'colsample_bylevel': 0.6955927796997213}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:55:13,452] Trial 22 finished with value: 0.6742447256241187 and parameters: {'depth': 7, 'learning_rate': 0.015938551366070947, 'l2_leaf_reg': 6, 'subsample': 0.7708895523772112, 'colsample_bylevel': 0.6325880821078459}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:56:33,393] Trial 23 finished with value: 0.8790342894332458 and parameters: {'depth': 8, 'learning_rate': 0.012170652752732923, 'l2_leaf_reg': 9, 'subsample': 0.9122574340651561, 'colsample_bylevel': 0.6903388332712725}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:57:32,158] Trial 24 finished with value: 0.9007509812751534 and parameters: {'depth': 7, 'learning_rate': 0.02435999667649301, 'l2_leaf_reg': 8, 'subsample': 0.9748260628973804, 'colsample_bylevel': 0.7508284614827541}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:58:55,215] Trial 25 finished with value: 0.897329694833807 and parameters: {'depth': 8, 'learning_rate': 0.025452831321065558, 'l2_leaf_reg': 8, 'subsample': 0.9633228846213854, 'colsample_bylevel': 0.7444854333190241}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 22:59:43,966] Trial 26 finished with value: 0.900225982154045 and parameters: {'depth': 6, 'learning_rate': 0.030845383084110403, 'l2_leaf_reg': 10, 'subsample': 0.9966925076008123, 'colsample_bylevel': 0.7752273708408279}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:00:36,404] Trial 27 finished with value: 0.7052992291532321 and parameters: {'depth': 7, 'learning_rate': 0.04798593427912619, 'l2_leaf_reg': 9, 'subsample': 0.9958592806541857, 'colsample_bylevel': 0.8984101441065054}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:01:58,878] Trial 28 finished with value: 0.6122934878259224 and parameters: {'depth': 8, 'learning_rate': 0.04064148278779024, 'l2_leaf_reg': 5, 'subsample': 0.9655198030298835, 'colsample_bylevel': 0.7975181768275433}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:02:47,012] Trial 29 finished with value: 0.9033132671487811 and parameters: {'depth': 6, 'learning_rate': 0.03243124622757723, 'l2_leaf_reg': 10, 'subsample': 0.9059274270927677, 'colsample_bylevel': 0.771690183978977}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:03:35,239] Trial 30 finished with value: 0.4730450539794137 and parameters: {'depth': 6, 'learning_rate': 0.031542150167436646, 'l2_leaf_reg': 8, 'subsample': 0.9036506638354792, 'colsample_bylevel': 0.8673420324305757}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:04:19,212] Trial 31 finished with value: 0.8998550070889092 and parameters: {'depth': 6, 'learning_rate': 0.03269630042386673, 'l2_leaf_reg': 10, 'subsample': 0.952151432848109, 'colsample_bylevel': 0.7722425521366413}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:05:03,138] Trial 32 finished with value: 0.8843922710875055 and parameters: {'depth': 6, 'learning_rate': 0.02404724197407203, 'l2_leaf_reg': 10, 'subsample': 0.9810415123494454, 'colsample_bylevel': 0.7796132711978109}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:05:35,741] Trial 33 finished with value: 0.8979424529799479 and parameters: {'depth': 5, 'learning_rate': 0.02905319452945129, 'l2_leaf_reg': 9, 'subsample': 0.9412217207161084, 'colsample_bylevel': 0.8240217870417239}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:06:21,774] Trial 34 finished with value: -2.2115393763781355 and parameters: {'depth': 6, 'learning_rate': 0.022363990858681872, 'l2_leaf_reg': 2, 'subsample': 0.9051560814925789, 'colsample_bylevel': 0.8069185745856421}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:07:17,475] Trial 35 finished with value: 0.6784451946257853 and parameters: {'depth': 7, 'learning_rate': 0.05402348967128944, 'l2_leaf_reg': 9, 'subsample': 0.9991417388769976, 'colsample_bylevel': 0.7342361310157628}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:07:56,129] Trial 36 finished with value: 0.8650069729271225 and parameters: {'depth': 6, 'learning_rate': 0.04227741211333935, 'l2_leaf_reg': 10, 'subsample': 0.8911735238170673, 'colsample_bylevel': 0.7562988927068289}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:08:25,660] Trial 37 finished with value: -2.3086339688331816 and parameters: {'depth': 5, 'learning_rate': 0.07120514630467034, 'l2_leaf_reg': 6, 'subsample': 0.8470991495509586, 'colsample_bylevel': 0.8721940382716475}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:09:16,719] Trial 38 finished with value: 0.8681196640876868 and parameters: {'depth': 7, 'learning_rate': 0.02685640011170472, 'l2_leaf_reg': 7, 'subsample': 0.9254824027701256, 'colsample_bylevel': 0.8139342380665106}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:10:17,359] Trial 39 finished with value: 0.8856227899413044 and parameters: {'depth': 7, 'learning_rate': 0.036514983574135615, 'l2_leaf_reg': 8, 'subsample': 0.9779023425184552, 'colsample_bylevel': 0.7948728917920096}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:11:08,030] Trial 40 finished with value: -0.9500903581377239 and parameters: {'depth': 7, 'learning_rate': 0.033360463921489725, 'l2_leaf_reg': 3, 'subsample': 0.9488101718870122, 'colsample_bylevel': 0.6364569651997346}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:11:47,215] Trial 41 finished with value: 0.901362367944904 and parameters: {'depth': 6, 'learning_rate': 0.029875848707195663, 'l2_leaf_reg': 10, 'subsample': 0.9566635361208923, 'colsample_bylevel': 0.790578763519578}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:12:29,128] Trial 42 finished with value: 0.8917354218323816 and parameters: {'depth': 6, 'learning_rate': 0.021376852975588667, 'l2_leaf_reg': 10, 'subsample': 0.9625500124802955, 'colsample_bylevel': 0.8522302265290026}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:13:00,654] Trial 43 finished with value: 0.8715713849177925 and parameters: {'depth': 5, 'learning_rate': 0.028230498702367917, 'l2_leaf_reg': 9, 'subsample': 0.9799134079644855, 'colsample_bylevel': 0.7851407449739829}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:13:40,676] Trial 44 finished with value: 0.8763473287076323 and parameters: {'depth': 6, 'learning_rate': 0.02476223891132639, 'l2_leaf_reg': 7, 'subsample': 0.884873144887656, 'colsample_bylevel': 0.7203602938225777}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:14:22,508] Trial 45 finished with value: 0.8870297946504432 and parameters: {'depth': 6, 'learning_rate': 0.017739963903006122, 'l2_leaf_reg': 10, 'subsample': 0.9192506186394782, 'colsample_bylevel': 0.7445968505301831}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:14:56,685] Trial 46 finished with value: 0.7905855897230571 and parameters: {'depth': 5, 'learning_rate': 0.029840656754203606, 'l2_leaf_reg': 9, 'subsample': 0.9362577516414247, 'colsample_bylevel': 0.8339414060838684}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:15:52,307] Trial 47 finished with value: 0.891850582860374 and parameters: {'depth': 7, 'learning_rate': 0.0390454880226623, 'l2_leaf_reg': 10, 'subsample': 0.9890749011172263, 'colsample_bylevel': 0.7732673507681546}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:16:44,390] Trial 48 finished with value: 0.8390127546154439 and parameters: {'depth': 6, 'learning_rate': 0.03237792595915834, 'l2_leaf_reg': 8, 'subsample': 0.956609816045802, 'colsample_bylevel': 0.9951047818170208}. Best is trial 13 with value: 0.9085775993770402.
# [I 2025-12-17 23:17:54,983] Trial 49 finished with value: 0.8567205233706985 and parameters: {'depth': 8, 'learning_rate': 0.046485156909977274, 'l2_leaf_reg': 9, 'subsample': 0.6036140352609692, 'colsample_bylevel': 0.7125579487294649}. Best is trial 13 with value: 0.9085775993770402.
# Meilleurs paramètres : {'depth': 8, 'learning_rate': 0.037131908555001, 'l2_leaf_reg': 8, 'subsample': 0.9481957612344127, 'colsample_bylevel': 0.6774015121344121}
# Meilleur score R² : 0.9085775993770402

# %%
# best_params = study.best_params
# best_params.update({
#     'iterations': 2000,
#     'loss_function': 'RMSE',
#     'eval_metric': 'RMSE',
#     'verbose': 500,
#     'random_seed': 42
# })
#
# final_model = CatBoostRegressor(**best_params)
# final_model.fit(X_train, y_train, eval_set=(X_val, y_val))
